# %%
# !pip install face_recognition
# Out:
# ...
#      |████████████████████████████████| 100.2MB 42kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566172 sha256=f8a29317c8a5649d343187d21847fffb674cdd6d4825e7187a50e6c87ceedd7f
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# ...

# %%
import cv2
import matplotlib.pyplot as plt

# %%
import face_recognition

from matplotlib.patches import Rectangle
from matplotlib.patches import Circle
import numpy as np

# %matplotlib inline

# %%
image=cv2.imread('/content/tendulkar.jpg')

image= cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

plt.imshow(image)

# %%
face_locations=face_recognition.face_locations(image)

number_of_faces=len(face_locations)

print('input image contains '+str(number_of_faces)+' faces')
# Out:
# input image contains 1 faces

# %%
plt.imshow(image)

ax=plt.gca()

for face_location in face_locations:
    top,right,bottom,left=face_location
    x,y,w,h=left,top,right,bottom

    rect=Rectangle((x,y),w-x,h-y,fill=False,color='red')
    ax.add_patch(rect)

plt.show()

# %% [markdown]
# Face Recognization using library

# %%
image=cv2.imread('/content/rahat.jpg')

rahat= cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

image=cv2.imread('/content/Modi.jpg')

Modi= cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

image=cv2.imread('/content/tendulkar.jpg')

tendulkar= cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

# %%
rahat_encoding=face_recognition.face_encodings(arjun)[0]

Modi_encoding=face_recognition.face_encodings(prabhas)[0]

tendulkar_encoding=face_recognition.face_encodings(nani)[0]

# %%
plt.title('PM Narendra Modi')
plt.imshow(Modi)

# %%
plt.title('Rahat Fateh ali khan')
plt.imshow(rahat)

# %%
known_faces=[rahat_encoding,Modi_encoding,tendulkar_encoding]

# %%
image=cv2.imread('/content/Pm Modi.jpeg')


unknown_image= cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

plt.imshow(unknown_image)

unknown_face_encodings=face_recognition.face_encodings(unknown_image)

# %%
from scipy.spatial import distance

for unknown_face_encoding in unknown_face_encodings:
    result=[]
    for known_face in known_faces:
        d=distance.euclidean(known_face,unknown_face_encoding)
        result.append(d)
    threshold=0.5
    result=np.array(result)<=threshold

    name='unknown'

    if result[0]:
        name='rahat'
    elif result[1]:
        name='Pm Narendra Modi'
    elif result[2]:
        name='Sachin tendulkar'
    print('found '+name+' in the image')
# Out:
# found Pm Narendra Modi in the image
